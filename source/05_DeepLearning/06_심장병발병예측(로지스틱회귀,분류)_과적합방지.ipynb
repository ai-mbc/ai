# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:20pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:20pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %%
import pandas as pd # 파일입력(read_excel), 교차표(crosstab), 원핫인코딩(get_dummies)
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split # 훈련셋과 시험셋 분리 함수
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from tensorflow.keras.models import Sequential, save_model, load_model
# 과적합을 줄이기 위한 방법 : dropout, 배치정규화, L2정규화
from tensorflow.keras.layers import Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.metrics import Recall, Precision, Accuracy
from tensorflow.keras.optimizers import Adam
# 데이터 불균형 극복 5.5 : 4.5 => 5:5
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt # 모델 학습과정 살펴보기
from sklearn.metrics import confusion_matrix # 혼동행렬

# %% [markdown]
# ```
# age: 나이 (년 단위)
# sex: 성별 (1 = 남성, 0 = 여성)
# cp (Chest Pain Type): 흉통의 유형 (0~3 값, 일반 협심증부터 무증상까지 분류)
# trestbps: 안정 시 혈압 (mmHg)
# chol: 혈청 콜레스테롤 수치 (mg/dl)
# fbs (Fasting Blood Sugar): 공복 혈당이 120 mg/dl 초과인지 여부 (1 = 참, 0 = 거짓)
# restecg: 안정 시 심전도(ECG) 결과 (0~2)
# thalach: 운동 시 달성한 최대 심박수
# exang: 운동 유발 협심증 여부 (1 = 있음, 0 = 없음)
# oldpeak: 휴식기에 비해 운동 시 나타나는 ST 부위 하강(ST depression) 정도
# slope: 최고 운동 시 ST 세그먼트의 기울기ca: 형광투시법으로 색칠된 주요 혈관 수 (0~3개)
# thal: 지중해빈혈 등 혈액 질환 여부 (정상, 고정 결함, 가역적 결함 등)
# target (Diagnosis): 심장질환 진단 결과 (0 = 정상, 1 = 심장질환 있음)
# ```

# %% [markdown]
# # 이진분류(로지스틱 회귀분석)
# - 1. 데이터셋 생성 & 전처리
#     * 엑셀 -> 데이터프레임 -> ?처리(결측치로 전환하여 결측치처리) -> X, y분리
#         -> X변수의 scale조정 -> train_test_split()을 이용하여 학습셋과 테스트셋을 분리
# - 2. 모델 생성(입력13,타겟1) - 과적합 고려 & 학습과정설정 & 학습
# - 3. 모델 평가(그래프, 평가, 혼동행렬=교차표)
# - 4. 모델 사용
#
# ## 1. 데이터셋 생성 & 전처리

# %%
df = pd.read_excel('data/heart-disease.xlsx',
                  # sheet_name='processed.cleveland'
                  )
df.head()
# Out:
#    age  sex  cp  treshtbps chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1        145  233    1        2      150      0      2.3      3
# 1   67    1   4        160  286    0        0      108      1      1.5      2
# 2   67    1   4        120    ?    0        2      129      1      2.6      2
# 3   37    1   3        130  250    0        0      187      0      3.5      3
# 4   41    0   2        130  204    0        2      172      0      1.4      1
#
#   ca hsl  heartDisease
# 0  0   6             0
# 1  3   3             1
# 2  2   7             1
# 3  0   3             0
# 4  0   3             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           303 non-null    int64
#  1   sex           303 non-null    int64
#  2   cp            303 non-null    int64
#  3   treshtbps     303 non-null    int64
#  4   chol          303 non-null    object
#  5   fbs           303 non-null    int64
#  6   restecg       303 non-null    int64
#  7   thalach       303 non-null    int64
#  8   exang         303 non-null    int64
#  9   oldpeak       303 non-null    float64
#  10  slope         303 non-null    int64
#  11  ca            303 non-null    object
#  12  hsl           303 non-null    object
#  13  heartDisease  303 non-null    int64
# dtypes: float64(1), int64(10), object(3)
# memory usage: 33.3+ KB

# %%
df.isnull().sum()
# Out:
# age             0
# sex             0
# cp              0
# treshtbps       0
# chol            0
# fbs             0
# restecg         0
# thalach         0
# exang           0
# oldpeak         0
# slope           0
# ca              0
# hsl             0
# heartDisease    0
# dtype: int64

# %%
df.isin(['?']).sum()
# Out:
# age             0
# sex             0
# cp              0
# treshtbps       0
# chol            1
# fbs             0
# restecg         0
# thalach         0
# exang           0
# oldpeak         0
# slope           0
# ca              4
# hsl             2
# heartDisease    0
# dtype: int64

# %%
df[(df['chol']=='?') | (df['ca']=='?') | (df['hsl']=='?') ]
# Out:
#      age  ...  heartDisease
# 2     67  ...             1
# 87    53  ...             0
# 166   52  ...             0
# 192   43  ...             1
# 266   52  ...             1
# 287   58  ...             0
# 302   38  ...             0
#
# [7 rows x 14 columns]

# %%
# 방법1 : ?가 있는 행을 삭제
drop_idx = df[(df['chol']=='?') | (df['ca']=='?') | (df['hsl']=='?') ].index # 삭제할 행
df = df.drop(drop_idx)

# %%
# 방법2:?를 결측치로 대체 => 결측치 삭제
df = df.replace('?', np.nan)
df[(df['chol']=='?') | (df['ca']=='?') | (df['hsl']=='?') ]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, treshtbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, hsl, heartDisease]
# Index: []

# %%
# 결측치가 포함된 데이터 추출
df[df['chol'].isna() | df['ca'].isna() | df['hsl'].isna()]
df[df.isna().any(axis=1)]
# Out:
#      age  ...  heartDisease
# 2     67  ...             1
# 87    53  ...             0
# 166   52  ...             0
# 192   43  ...             1
# 266   52  ...             1
# 287   58  ...             0
# 302   38  ...             0
#
# [7 rows x 14 columns]

# %%
# 결측치 처리 : 삭제(dropna) cf. fillna() apply()
df.dropna(how='any', inplace=True) # 결측치가 한열이라도 있으면 삭제
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, treshtbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, hsl, heartDisease]
# Index: []

# %%
df.isna().sum()
# Out:
# age             0
# sex             0
# cp              0
# treshtbps       0
# chol            0
# fbs             0
# restecg         0
# thalach         0
# exang           0
# oldpeak         0
# slope           0
# ca              0
# hsl             0
# heartDisease    0
# dtype: int64

# %%
df.shape
# Out:
# (296, 14)

# %%
# 타겟변수 분포가 균형적인지
df['heartDisease'].value_counts()/df.shape[0]
# Out:
# 0    0.540541
# 1    0.459459
# Name: heartDisease, dtype: float64

# %%
df['heartDisease'].value_counts(normalize=True)
# Out:
# 0    0.540541
# 1    0.459459
# Name: heartDisease, dtype: float64

# %%
# X, y분리
X = df.iloc[:, :-1].values # 맨마지막 열을 제외한 부분을 numpy배열
y = df.iloc[:, -1:].to_numpy() # 2차원 numpy 배열
X.shape, y.shape
# Out:
# ((296, 13), (296, 1))

# %%
# X변수의 scale조정
scaler = MinMaxScaler()
scaled_X = scaler.fit_transform(X)
print('원 데이터 :', X[0])
print('스케일 조정 데이터 :', scaled_X[0])
# Out:
# 원 데이터 : [63 1 1 145 233 1 2 150 0 2.3 3 0 6]
# 스케일 조정 데이터 : [0.70833333 1.         0.         0.48113208 0.24429224 1.
#  1.         0.60305344 0.         0.37096774 1.         0.
#  0.75      ]

# %%
# scaled_X와 y를 학습데이터셋:테스트셋 = 8:2
X_train, X_test, y_train, y_test = train_test_split(scaled_X,
                                    y,
                                    #train_size=0.8,
                                    test_size=0.2,
                                    random_state=7, # seed값
                                    stratify=y) # 층화추출

# %%
# 심장병 음성/양성 비율(y, y_train, y_test)
print(pd.DataFrame(y).value_counts(normalize=True))
print(pd.DataFrame(y_train).value_counts(normalize=True))
print(pd.DataFrame(y_test).value_counts(normalize=True))
# Out:
# 0    0.540541
# 1    0.459459
# dtype: float64
# 0    0.542373
# 1    0.457627
# dtype: float64
# 0    0.533333
# 1    0.466667
# dtype: float64

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((236, 13), (236, 1), (60, 13), (60, 1))

# %% [markdown]
# ## 2. 모델생성 & 학습과정 설정 & 학습
# - 모델 : 13 -> 32 -> 16 -> 8 -> 1
# - 학습과정을 시각화한 그래프를 보고 과적합 줄이기
# - 과적합 줄이기 위한 방법
#     * dropout : 학습할 때마다 일부 뉴런을 랜덤하게 끄기. 특정 뉴런 조합에 과하게 의존하는 것을 막아줘.
#     * BatchNormalization(배치 정규화) : 각 층의 출력을 정규화해서 더 안정적이고 빠르게 수렴하도록 도와줌
#     * L2 정규화(규제) : 가중치가 너무 커지지 않게 학습과정에서 미리 누름. 가중치가 크면 입력값이 살짝 바뀌어도 출력이 확 바뀜. 규제를세게(0.01) / 규제중간(0.001) / 규제약하게(0.0001)

# %%
model = Sequential(name='sequential')
model.add(Dense(units=32, input_dim=13, activation='relu', 
               kernel_regularizer=l2(0.001))) # L2정규화(규제)
model.add(BatchNormalization()) # 출력층의 정규화
model.add(Dropout(0.4))         # 40%를 랜덤하게 꺼서 과적합 방지
model.add(Dense(units=16, activation='relu', kernel_regularizer=l2(0.001) ))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(units=8, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Dense층 뒤에 배치정규화층에서의 파라미터 : Dense층(32) 출력갯수 * 4
    # ggamma(스케일) - 32 (학습됨)
    # beta(이동)     - 32 (학습됨)
    # moving_mean(이동평균) - 32 (학습안됨)
    # moving_variance(이동분산) - 32 (학습 안됨)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 32)                448
#
#  batch_normalization_9 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_25 (Dense)            (None, 16)                528
#
#  batch_normalization_10 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 16)                0
#
#  dense_26 (Dense)            (None, 8)                 136
#
#  batch_normalization_11 (Bat  (None, 8)                32
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 8)                 0
#
#  dense_27 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 1,345
# Trainable params: 1,233
# Non-trainable params: 112
# _________________________________________________________________

# %%
# 학습과정 설정
from tensorflow.keras.metrics import Recall, Precision, Accuracy
from tensorflow.keras.optimizers import Adam
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              # optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy', #Accuracy(name='accuracy'), 
                       Recall(name='recall'),        # 재현율(실제값 중심=1을 얼마나 잘 예측했는지)
                       Precision(name='precision')]) # 정밀도(예측값 중심=1이라고 예측한 것 중 얼마나 1인지)

# %%
# 클래스(0/1) 가중치 계산 (55:45 정도의 비율 => 50:50)
from sklearn.utils.class_weight import compute_class_weight
y_train_flat = y_train.flatten() #y_train.reshape(-1)
class_weight = compute_class_weight(
                class_weight='balanced',
                classes=np.unique(y_train_flat),
                y = y_train_flat )
print('class_weight :', class_weight)
class_weight_dict = dict(enumerate(class_weight))
print('학습시 가중치 조정값 :', class_weight_dict)
# y_train의 빈도수(0은?개, 1은?개)
values, counts = np.unique(y_train_flat, return_counts=True)
print('빈도수 :', dict(zip(values, counts)))
print(counts[0]*class_weight_dict[0], counts[1]*class_weight_dict[1])
# 빈도 분포
ratios = counts / counts.sum()
print(ratios[0]*class_weight_dict[0], ratios[1]*class_weight_dict[1])
# Out:
# class_weight : [0.921875   1.09259259]
# 학습시 가중치 조정값 : {0: 0.921875, 1: 1.0925925925925926}
# 빈도수 : {0: 128, 1: 108}
# 118.0 118.0
# 0.5 0.5

# %%
# callback 설정
# ReduceLROnPlateau : 성능이 정체되면  학습률(learing_rate)을 낮춰서 세밀하게 탐색
from tensorflow.keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                             factor=0.5, # 학습률을 원학습률의 절반으로
                             patience=7, # 7번 연속 개선이 없으면
                             min_lr=1e-6 # 학습률의 최소값 10의 -6승이하로는 안 내려가게 
                             )

# %%
# 학습
hist = model.fit(X_train, y_train, # 학습데이터
                epochs=200, # 학습횟수
                validation_split=0.2, # 학습데이터에서 20%를 검증데이터로 사용 
                class_weight=class_weight_dict, # loss계산시 얼마나 더 중요하게 취급될지의 가중치 
                callbacks=[reduce_lr],
                verbose=2)
# Out:
# Epoch 1/200
# 6/6 - 1s - loss: 0.9659 - accuracy: 0.4840 - recall: 0.6207 - precision: 0.4576 - val_loss: 0.7592 - val_accuracy: 0.5625 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 0.0010 - 1s/epoch - 229ms/step
# Epoch 2/200
# 6/6 - 0s - loss: 0.7945 - accuracy: 0.5585 - recall: 0.7011 - precision: 0.5169 - val_loss: 0.7510 - val_accuracy: 0.5208 - val_recall: 0.1905 - val_precision: 0.4000 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 3/200
# 6/6 - 0s - loss: 0.9055 - accuracy: 0.5213 - recall: 0.6667 - precision: 0.4874 - val_loss: 0.7459 - val_accuracy: 0.5625 - val_recall: 0.6667 - val_precision: 0.5000 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 4/200
# 6/6 - 0s - loss: 0.8722 - accuracy: 0.5266 - recall: 0.6782 - precision: 0.4917 - val_loss: 0.7451 - val_accuracy: 0.5417 - val_recall: 0.8095 - val_precision: 0.4857 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 5/200
# 6/6 - 0s - loss: 0.8524 - accuracy: 0.5532 - recall: 0.6667 - precision: 0.5133 - val_loss: 0.7443 - val_accuracy: 0.5000 - val_recall: 1.0000 - val_precision: 0.4667 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 6/200
# 6/6 - 0s - loss: 0.7930 - accuracy: 0.5426 - recall: 0.7126 - precision: 0.5041 - val_loss: 0.7444 - val_accuracy: 0.4375 - val_recall: 1.0000 - val_precision: 0.4375 - lr: 0.0010 - 98ms/epoch - 16ms/step
# Epoch 7/200
# 6/6 - 0s - loss: 0.8398 - accuracy: 0.5585 - recall: 0.7241 - precision: 0.5164 - val_loss: 0.7428 - val_accuracy: 0.4375 - val_recall: 1.0000 - val_precision: 0.4375 - lr: 0.0010 -
- val_accuracy: 0.4375 - val_recall: 1.0000 - val_precision: 0.4375 - lr: 5.0000e-04 - 73ms/epoch - 12ms/step
# Epoch 24/200
# 6/6 - 0s - loss: 0.6235 - accuracy: 0.6755 - recall: 0.7816 - precision: 0.6182 - val_loss: 0.7484 - val_accuracy: 0.4792 - val_recall: 1.0000 - val_precision: 0.4565 - lr: 5.0000e-04 - 77ms/epoch - 13ms/step
# Epoch 25/200
# 6/6 - 0s - loss: 0.5923 - accuracy: 0.7181 - recall: 0.8391 - precision: 0.6518 - val_loss: 0.7484 - val_accuracy: 0.4792 - val_recall: 1.0000 - val_precision: 0.4565 - lr: 5.0000e-04 - 80ms/epoch - 13ms/step
# Epoch 26/200
# 6/6 - 0s - loss: 0.6226 - accuracy: 0.6915 - recall: 0.8161 - precision: 0.6283 - val_loss: 0.7495 - val_accuracy: 0.4792 - val_recall: 1.0000 - val_precision: 0.4565 - lr: 5.0000e-04 - 65ms/epoch - 11ms/step
# Epoch 27/200
# 6/6 - 0s - loss: 0.6075 - accuracy: 0.7340 - recall: 0.8276 - precision: 0.6729 - val_loss: 0.7501 - val_accuracy: 0.5000 - val_recall: 1.0000 - val_precision: 0.4667 - lr: 5.0000e-04 - 71ms/epoch - 12ms/step
# Epoch 28/200
# 6/6 - 0s - loss: 0.6274 - accuracy: 0.6862 - recall: 0.7931 - precision: 0.6273 - val_loss: 0.7502 - val_accuracy: 0.5000 - val_recall: 1.0000 - val_precision: 0.4667 - lr: 2.5000e-04 - 74ms/epoch - 12ms/step
# Epoch 29/200
# 6/6 - 0s - loss: 0.5843 - accuracy: 0.7074 - recall: 0.8046 - precision: 0.6481 - val_loss: 0.7496 - val_accuracy: 0.5208 - val_recall: 1.0000 - val_precision: 0.4773 - lr: 2.5000e-04 - 83ms/epoch - 14ms/step
# Epoch 30/200
# 6/6 - 0s - loss: 0.6070 - accuracy: 0.7447 - recall: 0.8391 - precision: 0.6822 - val_loss: 0.7481 - val_accuracy: 0.5208 - val_recall: 1.0000 - val_precision: 0.4773 - lr: 2.5000e-04 - 76ms/epoch - 13ms/step
# Epoch 31/200
# 6/6 - 0s - loss: 0.6529 - accuracy: 0.6915 - recall: 0.8276 - precision: 0.6261 - val_loss: 0.7472 - val_accuracy: 0.5417 - val_recall: 1.0000 - val_precision: 0.4884 - lr: 2.5000e-04 - 79ms/epoch - 13ms/step
# Epoch 32/200
# 6/6 - 0s - loss: 0.6053 - accuracy: 0.7181 - recall: 0.8851 - precision: 0.6417 - val_loss: 0.7456 - val_accuracy: 0.5417 - val_recall: 1.0000 - val_precision: 0.4884 - lr: 2.5000e-04 - 76ms/epoch - 13ms/step
# Epoch 33/200
# 6/6 - 0s - loss: 0.6201 - accuracy: 0.6915 - recall: 0.8391 - precision: 0.6239 - val_loss: 0.7453 - val_accuracy: 0.5417 - val_recall: 1.0000 - val_precision: 0.4884 - lr: 2.5000e-04 - 68ms/epoch - 11ms/step
# Epoch 34/200
# 6/6 - 0s - loss: 0.6575 - accuracy: 0.6277 - recall: 0.7586 - precision: 0.5739 - val_loss: 0.7450 - val_accuracy: 0.5417 - val_recall: 1.0000 - val_precision: 0.4884 - lr: 2.5000e-04 - 68ms/epoch - 11ms/step
# Epoch 35/200
# 6/6 - 0s - loss: 0.6475 - accuracy: 0.7074 - recall: 0.8161 - precision: 0.6455 - val_loss: 0.7427 - val_accuracy: 0.5417 - val_recall: 1.0000 - val_precision: 0.4884 - lr: 1.2500e-04 - 70ms/epoch - 12ms/step
# Epoch 36/200
# 6/6 - 0s - loss: 0.6373 - accuracy: 0.6915 - recall: 0.7931 - precision: 0.6330 - val_loss: 0.7422 - val_accuracy: 0.5417 - val_recall: 1.0000 - val_precision: 0.4884 - lr: 1.2500e-04 - 66ms/epoch - 11ms/step
# Epoch 37/200
# 6/6 - 0s - loss: 0.6011 - accuracy: 0.7128 - recall: 0.8276 - precision: 0.6486 - val_loss: 0.7419 - val_accuracy: 0.5625 - val_recall: 1.0000 - val_precision: 0.5000 - lr: 1.2500e-04 - 76ms/epoch - 13ms/step
# Epoch 38/200
# 6/6 - 0s - loss: 0.6076 - accuracy: 0.7021 - recall: 0.8621 - precision: 0.6303 - val_loss: 0.7404 - val_accuracy: 0.5833 - val_recall: 1.0000 - val_precision: 0.5122 - lr: 1.2500e-04 - 74ms/epoch - 12ms/step
# Epoch 39/200
# 6/6 - 0s - loss: 0.6404 - accuracy: 0.6755 - recall: 0.8046 - precision: 0.6140 - val_loss: 0.7392 - val_accuracy: 0.5833 - val_recall: 1.0000 - val_precision: 0.5122 - lr: 1.2500e-04 - 70ms/epoch - 12ms/step
# Epoch 40/200
# 6/6 - 0s - loss: 0.5805 - accuracy: 0.7181 - recall: 0.8161 - precision: 0.6574 - val_loss: 0.7381 - val_accuracy: 0.5833 - val_recall: 1.0000 - val_precision: 0.5122 - lr: 1.2500e-04 - 70ms/epoch - 12ms/step
# Epoch 41/200
# 6/6 - 0s - loss: 0.5858 - accuracy: 0.7500 - recall: 0.8391 - precision: 0.6887 - val_loss: 0.7363 - val_accuracy: 0.5833 - val_recall: 1.0000 - val_precision: 0.5122 - lr: 1.2500e-04 - 69ms/epoch - 12ms/step
# Epoch 42/200
# 6/6 - 0s - loss: 0.6167 - accuracy: 0.6915 - recall: 0.8161 - precision: 0.6283 - val_loss: 0.7346 - val_accuracy: 0.5833 - val_recall: 1.0000 - val_precision: 0.5122 - lr: 1.2500e-04 - 67ms/epoch - 11ms/step
# Epoch 43/200
# 6/6 - 0s - loss: 0.6283 - accuracy: 0.6862 - recall: 0.8046 - precision: 0.6250 - val_loss: 0.7327 - val_accuracy: 0.5833 - val_recall: 1.0000 - val_precision: 0.5122 - lr: 1.2500e-04 - 71ms/epoch - 12ms/step
# Epoch 44/200
# 6/6 - 0s - loss: 0.5739 - accuracy: 0.7128 - recall: 0.8161 - precision: 0.6514 - val_loss: 0.7299 - val_accuracy: 0.6042 - val_recall: 1.0000 - val_precision: 0.5250 - lr: 1.2500e-04 - 63ms/epoch - 10ms/step
# Epoch 45/200
# 6/6 - 0s - loss: 0.6003 - accuracy: 0.7340 - recall: 0.8391 - precision: 0.6697 - val_loss: 0.7265 - val_accuracy: 0.6042 - val_recall: 1.0000 - val_precision: 0.5250 - lr: 1.2500e-04 - 67ms/epoch - 11ms/step
# Epoch 46/200
# 6/6 - 0s - loss: 0.6280 - accuracy: 0.6915 - recall: 0.8161 - precision: 0.6283 - val_loss: 0.7238 - val_accuracy: 0.6042 - val_recall: 1.0000 - val_precision: 0.5250 - lr: 1.2500e-04 - 72ms/epoch - 12ms/step
# Epoch 47/200
# 6/6 - 0s - loss: 0.6303 - accuracy: 0.6649 - recall: 0.7356 - precision: 0.6154 - val_loss: 0.7213 - val_accuracy: 0.6042 - val_recall: 1.0000 - val_precision: 0.5250 - lr: 1.2500e-04 - 71ms/epoch - 12ms/step
# Epoch
- val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 68ms/epoch - 11ms/step
# Epoch 167/200
# 6/6 - 0s - loss: 0.5405 - accuracy: 0.7766 - recall: 0.8736 - precision: 0.7103 - val_loss: 0.5729 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 70ms/epoch - 12ms/step
# Epoch 168/200
# 6/6 - 0s - loss: 0.5353 - accuracy: 0.7287 - recall: 0.8161 - precision: 0.6698 - val_loss: 0.5730 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 72ms/epoch - 12ms/step
# Epoch 169/200
# 6/6 - 0s - loss: 0.5674 - accuracy: 0.7553 - recall: 0.8046 - precision: 0.7071 - val_loss: 0.5729 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 71ms/epoch - 12ms/step
# Epoch 170/200
# 6/6 - 0s - loss: 0.5726 - accuracy: 0.7340 - recall: 0.8391 - precision: 0.6697 - val_loss: 0.5727 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 74ms/epoch - 12ms/step
# Epoch 171/200
# 6/6 - 0s - loss: 0.5303 - accuracy: 0.7500 - recall: 0.8621 - precision: 0.6818 - val_loss: 0.5719 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 71ms/epoch - 12ms/step
# Epoch 172/200
# 6/6 - 0s - loss: 0.5505 - accuracy: 0.7447 - recall: 0.8276 - precision: 0.6857 - val_loss: 0.5714 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 77ms/epoch - 13ms/step
# Epoch 173/200
# 6/6 - 0s - loss: 0.5061 - accuracy: 0.7872 - recall: 0.9080 - precision: 0.7117 - val_loss: 0.5716 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 70ms/epoch - 12ms/step
# Epoch 174/200
# 6/6 - 0s - loss: 0.5360 - accuracy: 0.7500 - recall: 0.8391 - precision: 0.6887 - val_loss: 0.5709 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 70ms/epoch - 12ms/step
# Epoch 175/200
# 6/6 - 0s - loss: 0.5463 - accuracy: 0.7713 - recall: 0.8621 - precision: 0.7075 - val_loss: 0.5709 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 74ms/epoch - 12ms/step
# Epoch 176/200
# 6/6 - 0s - loss: 0.5838 - accuracy: 0.7181 - recall: 0.8046 - precision: 0.6604 - val_loss: 0.5709 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 73ms/epoch - 12ms/step
# Epoch 177/200
# 6/6 - 0s - loss: 0.5969 - accuracy: 0.7287 - recall: 0.8161 - precision: 0.6698 - val_loss: 0.5702 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 75ms/epoch - 13ms/step
# Epoch 178/200
# 6/6 - 0s - loss: 0.5795 - accuracy: 0.7394 - recall: 0.8621 - precision: 0.6696 - val_loss: 0.5701 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 71ms/epoch - 12ms/step
# Epoch 179/200
# 6/6 - 0s - loss: 0.5585 - accuracy: 0.7500 - recall: 0.8506 - precision: 0.6852 - val_loss: 0.5695 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 107ms/epoch - 18ms/step
# Epoch 180/200
# 6/6 - 0s - loss: 0.5616 - accuracy: 0.7447 - recall: 0.8276 - precision: 0.6857 - val_loss: 0.5682 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 99ms/epoch - 16ms/step
# Epoch 181/200
# 6/6 - 0s - loss: 0.5753 - accuracy: 0.7287 - recall: 0.8276 - precision: 0.6667 - val_loss: 0.5680 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 - 88ms/epoch - 15ms/step
# Epoch 182/200
# 6/6 - 0s - loss: 0.5453 - accuracy: 0.7606 - recall: 0.8161 - precision: 0.7100 - val_loss: 0.5670 - val_accuracy: 0.6875 - val_recall: 0.9048 - val_precision: 0.5938 - lr: 6.2500e-05 -
- val_accuracy: 0.6667 - val_recall: 0.8571 - val_precision: 0.5806 - lr: 3.1250e-05 - 64ms/epoch - 11ms/step
# Epoch 200/200
# 6/6 - 0s - loss: 0.5304 - accuracy: 0.7553 - recall: 0.8736 - precision: 0.6847 - val_loss: 0.5651 - val_accuracy: 0.6667 - val_recall: 0.8571 - val_precision: 0.5806 - lr: 3.1250e-05 - 66ms/epoch - 11ms/step

# %% [markdown]
# ## 3. 모델 평가(그래프, 평가, 교차표)

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'recall', 'precision', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision'])

# %%
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
acc_ax.plot(hist.history['val_recall'], 'k', label='val_recall') # recall(검정)
acc_ax.plot(hist.history['val_precision'], 'k', label='val_precision') # precision(검정)

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')
acc_ax.legend(loc='center right')
plt.show()

# %%
# 평가
score = model.evaluate(X_test, y_test, verbose=0)
print(f'model loss : {score[0]}')
print(f'model accuracy : {score[1]*100:.2f}%')
print(f'model recall : {score[2]*100:.2f}%')
print(f'model precision : {score[3]*100:.2f}%')
# Out:
# model loss : 0.5802175998687744
# model accuracy : 68.33%
# model recall : 92.86%
# model precision : 60.47%

# %%
# 교차표(혼동행렬)
# 교차표에서의 실제값 : y_test.reshape(-1)
y_hat = (model.predict(X_test, verbose=0) > 0.5).astype(int).reshape(-1) # 예측값을 1차원
                                    # 0과 1의 기준값 0.5를 이동하면 recall과 precision이 바뀜
                                    # 0.5 -> 0.3 recall이 좋아짐(비추)
                                    # 0.5 -> 0.7 precision이 좋아짐(비추)

# %%
pd.crosstab(y_test.reshape(-1),
           y_hat,
           rownames=['실제값'],
           colnames=['예측값'])
# Out:
# 예측값   0   1
# 실제값
# 0    15  17
# 1     2  26

# %%
confusion_matrix(y_test, y_hat)
# Out:
# array([[15, 17],
#        [ 2, 26]], dtype=int64)

# %% [markdown]
# ## 4. 모델 사용
# - 저장/예측

# %%
# 딥러닝 모델 저장시 확장자 : h5, keras
model.save('model/06.h5')
save_model(model, 'model/06.h5')
model1 = load_model('model/06.h5')

# %%
data = [[63, 1, 1, 145, 233, 1, 2, 150, 0, 2.3, 3, 0, 6]]
input_data = scaler.transform(data)
(model.predict(input_data) > 0.5).astype(int)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[1]])

# %% [markdown]
# # 분류분석
# - 1. 데이터셋생성 & 전처리
#     * X_train, y_train, X_test, y_test -> y_train과 y_test 원핫인코딩
# - 2. 모델생성 & 학습과정 설정 & 모델 학습
# - 3. 모델평가(학습과정 시각화, 평가, 교차표 argmax이용)
# - 4. 모델 사용(저장, 예측)
#
# ## 1. 데이터셋 생성 & 전처리
# ```y_train, y_test원핫인코딩
#   0  -> 1 0
#   1  -> 0 1
# ```

# %%
Y_train = to_categorical(y_train, 2)
Y_test  = to_categorical(y_test)
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((236, 13), (236, 2), (60, 13), (60, 2))

# %%
X_train[0], Y_train[0]
# Out:
# (array([0.33333333, 0.        , 1.        , 0.41509434, 0.25114155,
#         0.        , 1.        , 0.61832061, 1.        , 0.03225806,
#         0.5       , 0.        , 0.        ]),
#  array([1., 0.], dtype=float32))

# %% [markdown]
# ## 2. 모델생성 & 학습과정 설정 & 학습

# %%
model = Sequential(name='sequential')
model.add(Dense(units=32, input_dim=13, activation='relu', 
               kernel_regularizer=l2(0.001))) # L2정규화(규제)
model.add(BatchNormalization()) # 출력층의 정규화
model.add(Dropout(0.4))         # 40%를 랜덤하게 꺼서 과적합 방지
model.add(Dense(units=16, activation='relu', kernel_regularizer=l2(0.001) ))
model.add(BatchNormalization()) 
model.add(Dropout(0.4))
model.add(Dense(units=8, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization()) 
model.add(Dropout(0.2))
model.add(Dense(units=2, activation='softmax'))#분류분석 출력층의 활성화함수
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                448
#
#  batch_normalization (BatchN  (None, 32)               128
#  ormalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  batch_normalization_1 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  batch_normalization_2 (Batc  (None, 8)                32
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 8)                 0
#
#  dense_3 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 1,354
# Trainable params: 1,242
# Non-trainable params: 112
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy",
             #optimizer=Adam(learning_rate=0.001),
             optimizer='adam',
             metrics=['accuracy', Precision(name='precision'), Recall(name='recall')] 
             )

# %%
# %%time
hist = model.fit(X_train, Y_train,
                epochs=200,
                validation_split=0.2,
                class_weight=class_weight_dict,
                callbacks=[reduce_lr],
                verbose=1)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 3s 69ms/step - loss: 0.7356 - accuracy: 0.6862 - precision: 0.6862 - recall: 0.6862 - val_loss: 0.7518 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - lr: 0.0010
# Epoch 2/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.7073 - accuracy: 0.6489 - precision: 0.6489 - recall: 0.6489 - val_loss: 0.7426 - val_accuracy: 0.4583 - val_precision: 0.4583 - val_recall: 0.4583 - lr: 0.0010
# Epoch 3/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7837 - accuracy: 0.6117 - precision: 0.6117 - recall: 0.6117 - val_loss: 0.7335 - val_accuracy: 0.4583 - val_precision: 0.4583 - val_recall: 0.4583 - lr: 0.0010
# Epoch 4/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.7024 - accuracy: 0.6277 - precision: 0.6277 - recall: 0.6277 - val_loss: 0.7237 - val_accuracy: 0.4792 - val_precision: 0.4792 - val_recall: 0.4792 - lr: 0.0010
# Epoch 5/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6530 - accuracy: 0.6489 - precision: 0.6489 - recall: 0.6489 - val_loss: 0.7154 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - lr: 0.0010
# Epoch 6/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6220 - accuracy: 0.7021 - precision: 0.7021 - recall: 0.7021 - val_loss: 0.7069 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - lr: 0.0010
# Epoch 7/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6565 - accuracy: 0.7074 - precision: 0.7074 - recall: 0.7074 - val_loss: 0.6983 - val_accuracy: 0.5417 - val_precision: 0.5417 - val_recall: 0.5417 - lr: 0.0010
# Epoch 8/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5990 - accuracy: 0.7128 - precision: 0.7128 - recall: 0.7128 - val_loss: 0.6899 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - lr: 0.0010
# Epoch 9/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6976 - accuracy: 0.6755 - precision: 0.6755 - recall: 0.6755 - val_loss: 0.6820 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833 - lr: 0.0010
# Epoch 10/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6181 - accuracy: 0.7394 - precision: 0.7394 - recall: 0.7394 - val_loss: 0.6733 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - lr: 0.0010
# Epoch 11/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5294 - accuracy: 0.7713 - precision: 0.7713 - recall: 0.7713 - val_loss: 0.6632 - val_accuracy: 0.6667 - val_precision: 0.6667 - val_recall: 0.6667 - lr: 0.0010
# Epoch 12/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5971 - accuracy: 0.7553 - precision: 0.7553 - recall: 0.7553 - val_loss: 0.6557 - val_accuracy: 0.7083 - val_precision: 0.7083 - val_recall: 0.7083 - lr: 0.0010
# Epoch 13/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.
- val_accuracy: 0.7708 - val_precision: 0.7708 - val_recall: 0.7708 - lr: 1.2500e-04
# Epoch 101/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4521 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4921 - val_accuracy: 0.7708 - val_precision: 0.7708 - val_recall: 0.7708 - lr: 1.2500e-04
# Epoch 102/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4352 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4925 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.2500e-04
# Epoch 103/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4070 - accuracy: 0.8777 - precision: 0.8777 - recall: 0.8777 - val_loss: 0.4927 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.2500e-04
# Epoch 104/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4529 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4927 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.2500e-04
# Epoch 105/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4683 - accuracy: 0.8032 - precision: 0.8032 - recall: 0.8032 - val_loss: 0.4928 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.2500e-04
# Epoch 106/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4641 - accuracy: 0.7926 - precision: 0.7926 - recall: 0.7926 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.2500e-04
# Epoch 107/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4787 - accuracy: 0.7926 - precision: 0.7926 - recall: 0.7926 - val_loss: 0.4921 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 108/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4295 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 109/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4221 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4923 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 110/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4467 - accuracy: 0.8564 - precision: 0.8564 - recall: 0.8564 - val_loss: 0.4923 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 111/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4656 - accuracy: 0.7926 - precision: 0.7926 - recall: 0.7926 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 112/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4824 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4923 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 113/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4381 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4925 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 6.2500e-05
# Epoch 114/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4361 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - val_loss: 0.4927 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 115/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4310 - accuracy: 0.8564 - precision: 0.8564 - recall: 0.8564 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 116/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4618 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 117/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4382 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 118/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4575 - accuracy: 0.8138 - precision: 0.8138 - recall: 0.8138 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 119/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4698 - accuracy: 0.7766 - precision: 0.7766 - recall: 0.7766 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 120/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4439 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4915 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.1250e-05
# Epoch 121/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3990 - accuracy: 0.8617 - precision: 0.8617 - recall: 0.8617 - val_loss: 0.4917 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 122/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4685 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4910 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 123/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4692 - accuracy: 0.7979 - precision: 0.7979 - recall: 0.7979 - val_loss: 0.4911 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 124/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4733 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4908 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 125/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4754 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4908 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 126/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4343 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4908 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 127/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4523 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - val_loss: 0.4906 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 128/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4184 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4907 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 129/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4430 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4905 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 130/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4083 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4904 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 131/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4387 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4903 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 132/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4313 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4905 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 133/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4414 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - val_loss: 0.4909 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 134/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4535 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4911 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 135/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4351 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4912 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 136/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4204 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4913 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 137/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4215 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4915 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 138/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4375 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4917 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.5625e-05
# Epoch 139/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4401 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 140/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4787 - accuracy: 0.7872 - precision: 0.7872 - recall: 0.7872 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 141/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3957 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 142/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4902 - accuracy: 0.7979 - precision: 0.7979 - recall: 0.7979 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 143/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4565 - accuracy: 0.8617 - precision: 0.8617 - recall: 0.8617 - val_loss: 0.4921 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 144/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4564 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 145/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4280 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 7.8125e-06
# Epoch 146/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4649 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 147/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4133 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - val_loss: 0.4921 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 148/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4168 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4921 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 149/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4494 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4921 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 150/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4433 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4923 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 151/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4132 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 152/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4613 - accuracy: 0.7979 - precision: 0.7979 - recall: 0.7979 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 3.9063e-06
# Epoch 153/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4421 - accuracy: 0.8191 - precision: 0.8191 - recall: 0.8191 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 154/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4110 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 155/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4811 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 156/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4340 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 157/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4327 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4921 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 158/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4395 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 159/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4369 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4922 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.9531e-06
# Epoch 160/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4291 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 161/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4542 - accuracy: 0.8191 - precision: 0.8191 - recall: 0.8191 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 162/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4429 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4920 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 163/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4155 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 164/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4259 - accuracy: 0.8191 - precision: 0.8191 - recall: 0.8191 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 165/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4596 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4911 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 166/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4435 - accuracy: 0.8138 - precision: 0.8138 - recall: 0.8138 - val_loss: 0.4910 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 167/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3846 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - val_loss: 0.4912 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 168/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4516 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4915 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 169/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4096 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4917 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 170/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4939 - accuracy: 0.7979 - precision: 0.7979 - recall: 0.7979 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 171/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4360 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4915 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 172/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4502 - accuracy: 0.8032 - precision: 0.8032 - recall: 0.8032 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 173/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4581 - accuracy: 0.8032 - precision: 0.8032 - recall: 0.8032 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 174/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4338 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - val_loss: 0.4919 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 175/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4003 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 176/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5055 - accuracy: 0.8032 - precision: 0.8032 - recall: 0.8032 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 177/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4408 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 178/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4322 - accuracy: 0.8138 - precision: 0.8138 - recall: 0.8138 - val_loss: 0.4912 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 179/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4238 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 180/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4615 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4913 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 181/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4443 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4913 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 182/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4615 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4913 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 183/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4528 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 184/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4422 - accuracy: 0.8404 - precision: 0.8404 - recall: 0.8404 - val_loss: 0.4915 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 185/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4578 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 186/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4189 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 187/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4162 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - val_loss: 0.4917 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 188/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4522 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 189/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4635 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4915 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 190/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4384 - accuracy: 0.8138 - precision: 0.8138 - recall: 0.8138 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 191/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4403 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 192/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4704 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 193/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4699 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 194/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4081 - accuracy: 0.8564 - precision: 0.8564 - recall: 0.8564 - val_loss: 0.4916 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 195/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4203 - accuracy: 0.8777 - precision: 0.8777 - recall: 0.8777 - val_loss: 0.4912 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 196/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4194 - accuracy: 0.8564 - precision: 0.8564 - recall: 0.8564 - val_loss: 0.4911 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 197/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4989 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 198/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4625 - accuracy: 0.8085 - precision: 0.8085 - recall: 0.8085 - val_loss: 0.4914 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 199/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4279 - accuracy: 0.8138 - precision: 0.8138 - recall: 0.8138 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# Epoch 200/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4446 - accuracy: 0.8351 - precision: 0.8351 - recall: 0.8351 - val_loss: 0.4918 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - lr: 1.0000e-06
# CPU times: total: 24.3 s
# Wall time: 18.9 s

# %% [markdown]
# ## 3. 모델평가(시각화, 평가, 교차표)

# %%
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
acc_ax.plot(hist.history['val_recall'], 'k', label='val_recall', alpha=0.3) # recall(검정)
acc_ax.plot(hist.history['val_precision'], 'k', label='val_precision', alpha=0.3) # precision(검정)

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')
acc_ax.legend(loc='center right')
plt.show()
