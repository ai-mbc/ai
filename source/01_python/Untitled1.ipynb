# %%
name='홍길동'
age=30
print(f'{name:^}님의 나이는 {age}입니다' )
# Out:
# 홍길동님의 나이는 30입니다

# %%
a=int(input('가로'))
b=int(input('세로'))
c=a*b
d=2*a+2*b
print(f'넓이:{c}')
print(f'둘레:{d}')
# Out:
# 가로3
# 세로4
# 넓이:12
# 둘레:14

# %%
a = int(input('가로 '))
b = int(input('세로 '))
c = a * b
d = 2 * a + 2 * b
print(f'넓이: {c}')
print(f'둘레: {d}')
