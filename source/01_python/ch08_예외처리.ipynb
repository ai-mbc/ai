# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
.inner_cell{font-size:20pt;}
div.text_cell_render pre code {font-size:20pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:20pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:20pt;padding:5px;}
table.dataframe{font-size:20px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# .inner_cell{font-size:20pt;}
# div.text_cell_render pre code {font-size:20pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:20pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:20pt;padding:5px;}
# table.dataframe{font-size:20px;}
# </style>

# %% [markdown]
# <font size="6" color="red">ch08. 예외처리</font>
# ```
# - 에러
#     (1) 문법에러 : 문법적으로 나타나는 에러
#     (2) 실행에러
#         * 논리 에러(프로그래머가 잘못 작성해서 이상한 결과가 나오는 경우)
#         * 시스템 에러(프로그래머의 의지와 상관없이 나타나는 시스템 에러)
#         * 예외사항 : 정상적으로 프로그램이 동작하는 과정에서 나타나는 에러
#                     (프로그램 실행 중 발생하는 예기치 않는 사건)
# ```
# # 1절. 예외처리 필요성
# - 예외가 날 가능성이 있는 부분에 대해 미리 예상하고, 그에 대한 처리를 프로그래밍하는 것.
#     (이유 : 안정적으로 실행할 수 있도록 함)
#
# ```
# 파일이 없거나 쓰기 금지로 인한 오류
# 데이터베이스 프로그래밍 시 제약조건 등에 의한 데이터베이스 서버 오류
# 네트워크 프로그래밍 시 네트워크 연결 실패로 인한 오류
# 리스트 또는 튜플의 인덱스를 벗어난 참조로 인한 오류
#
# ```

# %%
filename = input('파일명?') # test.txt
# 한글 인코딩 방법 : 한글조합형(utf-8), 한글완성형(euc-kr < cp949)-euc-kr:2350개문자이외는 깨짐
# 한글문자 1만1172자(초성쌍자음19개 * 중성 21 * 종성 ㄵ같은거포함 28개)
f = open('data/'+filename, 'r') # 읽기 전용으로 파일을 열기(읽기 전용 stream객체 생성)
print(f.read())
f.close()
# Out:
# 파일명?test.txt
# test.txt
# Hello World
# 더출력하고 싶어

# %%
filename = input('파일명?') # 없는 파일 입력시 FileNotFoundError
# 한글 인코딩 방법 : 한글조합형(utf-8), 한글완성형(euc-kr < cp949)-euc-kr:2350개문자이외는 깨짐
# 한글문자 1만1172자(초성쌍자음19개 * 중성 21 * 종성 ㄵ같은거포함 28개)
f = open('data/'+filename, 'r') # 읽기 전용으로 파일을 열기(읽기 전용 stream객체 생성)
print(f.read())
f.close()
# Out:
# 파일명?a.txt
# ---------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[4], line 4
#       1 filename = input('파일명?') # 없는 파일
#       2 # 한글 인코딩 방법 : 한글조합형(utf-8), 한글완성형(euc-kr < cp949)-euc-kr:2350개문자이외는 깨짐
#       3 # 한글문자 1만1172자(초성쌍자음19개 * 중성 21 * 종성 ㄵ같은거포함 28개)
# ----> 4 f = open('data/'+filename, 'r') # 읽기 전용으로 파일을 열기(읽기 전용 stream객체 생성)
#       5 print(f.read())
#       6 f.close()
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/a.txt'

# %%
filename = input('파일명?') # ch08.txt(UTF-8)입력시 UnicodeDecodeError
# 한글 인코딩 방법 : 한글조합형(utf-8), 한글완성형(euc-kr < cp949)-euc-kr:2350개문자이외는 깨짐
# 한글문자 1만1172자(초성쌍자음19개 * 중성 21 * 종성 ㄵ같은거포함 28개)
f = open('data/'+filename, 'r') # 읽기 전용으로 파일을 열기(읽기 전용 stream객체 생성)
print(f.read())
f.close()
# Out:
# 파일명?ch08.txt
# ---------------------
# UnicodeDecodeErrorTraceback (most recent call last)
# Cell In[7], line 5
#       2 # 한글 인코딩 방법 : 한글조합형(utf-8), 한글완성형(euc-kr < cp949)-euc-kr:2350개문자이외는 깨짐
#       3 # 한글문자 1만1172자(초성쌍자음19개 * 중성 21 * 종성 ㄵ같은거포함 28개)
#       4 f = open('data/'+filename, 'r') # 읽기 전용으로 파일을 열기(읽기 전용 stream객체 생성)
# ----> 5 print(f.read())
#       6 f.close()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 24: illegal multibyte sequence

# %%
4/0 # ZeroDivisionError
# Out:
# ---------------------
# ZeroDivisionErrorTraceback (most recent call last)
# Cell In[8], line 1
# ----> 1 4/0
#
# ZeroDivisionError: division by zero

# %%
a = [1, 2, 3] # IndexError
a[3]
# Out:
# ---------------------
# IndexErrorTraceback (most recent call last)
# Cell In[9], line 2
#       1 a = [1, 2, 3]
# ----> 2 a[3]
#
# IndexError: list index out of range

# %% [markdown]
# # 2절. try ~ except로 예외처리
# ## 2.1 try~except
# ```
# try:
#     예외가 발생할 가능성이 있는 명령어들
# except:
#     예외가 발생했을 경우 실행할 명령어들
# ```

# %%
# 100을 입력받은 정수값으로 나눠 출력
x = int(input('정수를 입력하세요 >'))
print('입력한 정수는 {}'.format(x))
print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
# ZeroDivisionError : "division by zero" 
#                     0을 입력했을 때 예외타입
# ValueError : invalid literal for int() with base 10: 'a'
#              invalid literal(잘못된 문자)를 입력할 경우
print('DONE')
# Out:
# 정수를 입력하세요 >0
# 입력한 정수는 0
# -----------------------------
# ZeroDivisionErrorTraceback (most recent call last)
# Cell In[4], line 4
#       2 x = int(input('정수를 입력하세요 >'))
#       3 print('입력한 정수는 {}'.format(x))
# ----> 4 print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
#       5 # ZeroDivisionError : "division by zero"
#       6 #                     0을 입력했을 때 예외타입
#       7 # ValueError : invalid literal for int() with base 10: 'a'
#       8 #              invalid literal(잘못된 문자)를 입력할 경우
#       9 print('DONE')
#
# ZeroDivisionError: division by zero

# %%
# 100을 입력받은 정수값으로 나눠 출력
# ZeroDivisionError : "division by zero" 
# ValueError : invalid literal for int() with base 10: 'a'
try:
    x = int(input('정수를 입력하세요 >'))
    print('입력한 정수는 {}'.format(x))
    print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
except:
    print('나누기에 유효한 정수가 아닙니다')
print('DONE')
# Out:
# 정수를 입력하세요 >ㅁ
# 나누기에 유효한 정수가 아닙니다
# DONE

# %%
# 100을 나눌 유효한 정수를 입력할 때까지 정수를 입력받아 유효한 정수를 입력하면 입력한 정수와 100으로 나눈 수를 출력
# ZeroDivisionError : "division by zero" 
# ValueError : invalid literal for int() with base 10: 'a'
while True:
    try:
        x = int(input('정수를 입력하세요 >'))
        print('입력한 정수는 {}'.format(x))
        print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
        break
    except:
        print('나누기에 유효한 정수가 아닙니다')
print('DONE')
# Out:
# 정수를 입력하세요 >a
# 나누기에 유효한 정수가 아닙니다
# 정수를 입력하세요 >
# 나누기에 유효한 정수가 아닙니다
# 정수를 입력하세요 >0
# 입력한 정수는 0
# 나누기에 유효한 정수가 아닙니다
# 정수를 입력하세요 >3
# 입력한 정수는 3
# 100을 입력한 정수로 나누면 33.33
# DONE

# %% [markdown]
# ## 2.2 예외를 지정한 처리
# ```
# try:
#     예외가 발생할 수도 있는 문장들
# except 예외타입1:
#     해당 예외가 발생할 경우 실행할 문장
# except 예외타입2:
#     해당 예외가 발생할 경우 실행할 문장
# ```
# **여러 예외처리를 할 경우 상위 예외타입은 아래로**

# %%
# 100을 나눌 유효한 정수를 입력할 때까지 정수를 입력받아 유효한 정수를 입력하면 입력한 정수와 100으로 나눈 수를 출력
# ZeroDivisionError : "division by zero" 
# ValueError : invalid literal for int() with base 10: 'a'
while True:
    try:
        x = int(input('100을 나눌 정수를 입력하세요 >'))
        print('입력한 정수는 {}'.format(x))
        print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
        break    
    except ValueError:
        print('정수가 아닙니다. 다시 입력하세요')
    except ZeroDivisionError:
        print('0으로 나눌 수 없습니다. 다시 입력하세요')    
    except Exception:
        print('원인 모를 예외가 발생했습니다. 다시 입력하세요')
print('DONE')
# Out:
# 100을 나눌 정수를 입력하세요 >ㅁ
# 정수가 아닙니다. 다시 입력하세요
# 100을 나눌 정수를 입력하세요 >0
# 입력한 정수는 0
# 0으로 나눌 수 없습니다. 다시 입력하세요
# 100을 나눌 정수를 입력하세요 >2
# 입력한 정수는 2
# 100을 입력한 정수로 나누면 50.00
# DONE

# %%
# 100을 나눌 유효한 정수를 입력할 때까지 정수를 입력받아 유효한 정수를 입력하면 입력한 정수와 100으로 나눈 수를 출력
# ZeroDivisionError : "division by zero" 
# ValueError : invalid literal for int() with base 10: 'a'
while True:
    try:
        x = int(input('100을 나눌 정수를 입력하세요 >'))
        print('입력한 정수는 {}'.format(x))
        print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
        break    
    except (ValueError, ZeroDivisionError):
        print('100으로 나눌 수 있는 정수가 아닙니다. 다시 입력하세요')   
    except Exception:
        print('원인 모를 예외가 발생했습니다. 다시 입력하세요')
print('DONE')
# Out:
# 100을 나눌 정수를 입력하세요 >ㅁ
# 100으로 나눌 수 있는 정수가 아닙니다. 다시 입력하세요
# 100을 나눌 정수를 입력하세요 >0
# 입력한 정수는 0
# 100으로 나눌 수 있는 정수가 아닙니다. 다시 입력하세요
# 100을 나눌 정수를 입력하세요 >2
# 입력한 정수는 2
# 100을 입력한 정수로 나누면 50.00
# DONE

# %% [markdown]
# ## 2.3 예외인수(e)
# ```
# try:
#     예외가 발생할 수도 있는 문장들
# except 예외타입 as e:
#     print(e.args[0])
#     print(e)
# ```

# %%
e = ZeroDivisionError("division by zero") # 예외가 발생되면 자동적으로 예외객체가 생성
e.args[0]
# Out:
# 'division by zero'

# %%
while True:
    try:
        x = int(input('100을 나눌 정수를 입력하세요 >'))
        print('입력한 정수는 {}'.format(x))
        print('100을 입력한 정수로 나누면 {:.2f}'.format(100/x))
        break    
    except (ValueError, ZeroDivisionError) as e:
        print(e)   
        # print(e.args[0])
    except Exception:
        print('원인 모를 예외가 발생했습니다. 다시 입력하세요')
print('DONE')
# Out:
# 100을 나눌 정수를 입력하세요 >0
# 입력한 정수는 0
# division by zero
# division by zero
# 100을 나눌 정수를 입력하세요 >a
# invalid literal for int() with base 10: 'a'
# invalid literal for int() with base 10: 'a'
# 100을 나눌 정수를 입력하세요 >3
# 입력한 정수는 3
# 100을 입력한 정수로 나누면 33.33
# DONE

# %% [markdown]
# ```
# try:
#     명령어들
# except [예외타입 [as e]]:
#     해당 예외타입시 수행할 명령어
# [else:
#     try블록을 다 수행한 후 실행할 명령어 ]
# finally:
#     try블록이나 except블록을 수행한 후 실행
# ```

# %%
try:
    f = open('data/ch08.txt', 'r') #encoding='utf-8') # FileNotFoundError
    data = f.read() # UnicodeDecodeError
except (FileNotFoundError, UnicodeDecodeError) as e:
    print(e)
else:
    print(data) # try블록을 다 실행한 후 실행
finally:
    f.close()
# Out:
# 'cp949' codec can't decode byte 0xec in position 24: illegal multibyte sequence

# %%
try:
    f = open('data/ch08.txt', 'r') #encoding='utf-8') # FileNotFoundError
    data = f.read() # UnicodeDecodeError
    print(data)
except (FileNotFoundError, UnicodeDecodeError) as e:
    print(e)    
finally:
    f.close() # try블록 수행 후 또는 except블록 수행 후 실행
# Out:
# 'cp949' codec can't decode byte 0xec in position 24: illegal multibyte sequence

# %% [markdown]
# # 3절. raise
# - 강제 예외 발생

# %%
raise ZeroDivisionError("예외가 발생했어요")
# Out:
# -----------------------------
# ZeroDivisionErrorTraceback (most recent call last)
# Cell In[32], line 1
# ----> 1 raise ZeroDivisionError("예외가 발생했어요")
#
# ZeroDivisionError: 예외가 발생했어요

# %%
100/0
# Out:
# -----------------------------
# ZeroDivisionErrorTraceback (most recent call last)
# Cell In[33], line 1
# ----> 1 100/0
#
# ZeroDivisionError: division by zero

# %%
# 사용자 정의 예외 : Exception클래스를 상속받은 클래스
class LengthZeroError(Exception):
    '매개변수 길이가 0일때 발생하는 예외'
    def __init__(self, message):
        super().__init__(message) # 부모클래스의 생성자에서 예외메세지를 셋팅

# %%
def args_print(*data): # 튜플 매개변수
    if len(data)==0:
        raise LengthZeroError("매개변수 길이가 0이면 예외발생(사용자 정의 예외)")
    for item in data:
        print(item, end=' ')
    print('등을 입력하셨습니다')

# %%
args_print('a','b','c')
# Out:
# a b c 등을 입력하셨습니다

# %%
args_print()
# Out:
# -----------------------------
# LengthZeroErrorTraceback (most recent call last)
# Cell In[47], line 1
# ----> 1 args_print()
#
# Cell In[42], line 3, in args_print(*data)
#       1 def args_print(*data): # 튜플 매개변수
#       2     if len(data)==0:
# ----> 3         raise LengthZeroError("매개변수 길이가 0이면 예외발생(사용자 정의 예외)")
#       4     for item in data:
#       5         print(item, end=' ')
#
# LengthZeroError: 매개변수 길이가 0이면 예외발생(사용자 정의 예외)

# %%
try:
    args_print()
except Exception as e:
    print(e)
# Out:
# 매개변수 길이가 0이면 예외발생(사용자 정의 예외)

# %% [markdown]
# # 4절. 추상클래스
# - 추상클래스 : 추상메소드가 1개이상 포함된 객체를 생성할 수 없는 클래스
# - 추상메소드 : 호출할 수 없는 메소드. 상속받은 클래스에서 재정의를 강요할 때
# - 파이썬에서의 추상클래스는 raise를 이용하거나, @abstractmethod을 이용하여 추상메소드를 구현

# %%
class Shape:
    def __init__(self):
        raise NotImplementedError('객체를 생성할 수 없음')        
    def calc_area(self):
        raise NotImplementedError('추상메소드')

# %%
from abc import abstractmethod, ABC
class Shape(ABC):
    @abstractmethod
    def __init__(self):
        pass     
    @abstractmethod
    def calc_area(self):
        pass

# %%
s = Shape()
# Out:
# -----------------------------
# TypeErrorTraceback (most recent call last)
# Cell In[78], line 1
# ----> 1 s = Shape()
#
# TypeError: Can't instantiate abstract class Shape with abstract methods __init__, calc_area

# %%
class Circle(Shape):    
    def __init__(self, r=3):
        self.r = r
    def calc_area(self):
        import numpy as np
        return np.pi * (self.r**2)

# %%
myCircle = Circle(5)
myCircle.calc_area()
# Out:
# 78.53981633974483

# %% [markdown]
# # 5절. 파일 정리 작업(with절 이용)

# %%
try:
    f = open('data/test.txt', 'r', encoding='cp949') # windows에서기본값 cp949 / Linux나 MacOX는 utf-8
    lines = f.readlines() # 한줄한줄 모든 줄을 읽어 list로 return
    print(lines)
except (FileNotFoundError, UnicodeDecodeError) as e:
    print(e)
finally:
    f.close() # 제일 중요
# Out:
# ['test.txt\n', 'Hello World\n', '더출력하고 싶어']

# %%
# with절 이후에는 자동적으로 close() 실행
try:
    with open('data/ch08.txt', 'r') as f:
        lines = f.readlines()
    print(lines)
except (FileNotFoundError, UnicodeDecodeError) as e:
    print(e)
# Out:
# 'cp949' codec can't decode byte 0xec in position 24: illegal multibyte sequence

# %%
# 9장 파일 입출력(i/o)
with open('data/ch08.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()
print(lines)
# Out:
# ['ch08.txt\n', 'Hello\n', 'World\n', '안녕']

# %% [markdown]
# # 6절. 연습문제
# ## 실습형

# %%
float("1"), float("1.5")
# Out:
# (1.0, 1.5)

# %%
# 실습형1
while True:
    try:
        num1 = float(input('첫번째 수를 입력하세요 >'))
        num2 = float(input('두번째 수를 입력하세요 >'))
        print('입력한 수는 {}와 {}'.format(num1, num2))
        print('{}을 {}으로 나누면 {}'.format(num1, num2, num1/num2))
        break
    except :
        print('유효한 숫자가 아닙니다. 다시 시도하세요')
# Out:
# 첫번째 수를 입력하세요 >a
# 유효한 숫자가 아닙니다. 다시 시도하세요
# 첫번째 수를 입력하세요 >9
# 두번째 수를 입력하세요 >a
# 유효한 숫자가 아닙니다. 다시 시도하세요
# 첫번째 수를 입력하세요 >9
# 두번째 수를 입력하세요 >0
# 입력한 수는 9.0와 0.0
# 유효한 숫자가 아닙니다. 다시 시도하세요
# 첫번째 수를 입력하세요 >5
# 두번째 수를 입력하세요 >2
# 입력한 수는 5.0와 2.0
# 5.0을 2.0으로 나누면 2.5

# %%
def isit_int(float_num):
    return int(float_num) if float_num%1==0 else float_num

# %%
# 실습형2
while True:
    try:
        num1 = float(input('첫번째 수를 입력하세요 >'))
        num2 = float(input('두번째 수를 입력하세요 >'))
        print('입력한 수는 {}와 {}'.format(num1, num2))
        result = num1 / num2
        num1 = isit_int(num1)
        num2 = isit_int(num2)
        result = isit_int(result)
#         num1 = int(num1) if num1.is_integer() else num1
#         num2 = int(num2) if num2.is_integer() else num2
#         result = int(result) if result.is_integer() else result
        print('{}을 {}으로 나누면 {}'.format(num1, num2, result))
        break
    except ValueError:
        print('유효한 숫자가 아닙니다. 다시 시도하세요')
    except ZeroDivisionError:
        print('0으로 나눌 수 없습니다. 다시 시도하세요')
# Out:
# 첫번째 수를 입력하세요 >10
# 두번째 수를 입력하세요 >5
# 입력한 수는 10.0와 5.0
# 10을 5으로 나누면 2

# %% [markdown]
# ## 문제풀이형
# - 1 (3)
# - 2 (2)
# - 3 (4)
# - 4 (3)
