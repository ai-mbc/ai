# %%
a = int(input('가로> '))
b = int(input('세로> '))

c = a * b
d = 2 * a + 2 * b

print(f'넓이: {c}')
print(f'둘레: {d}')
# Out:
# 가로> 4
# 세로> 5
# 넓이: 20
# 둘레: 18

# %%
print(f'넓이:{c}')
# Out:
# 넓이:20

# %%
#초를 입력받아서 분초로 출력
a=int(input('초'))
b=a//60
c=a%60
print(f'{b}분 {c}초')
# Out:
# 초678
# 11분 18초

# %%
a=int(input('가로'))
b=int(input('세로'))
c=a*b
d=2*(a+b)
print(f'넓이{c}')
print(f'둘레{d}')
# Out:
# 가로4
# 세로5
# 넓이20
# 둘레18

# %%
num=a,b
a=int(input('첫번째 정수를 입력하세요'))
b=int(input('두번째 정수를 입력하세요'))
print(f'두 수의 합은 {a+b}')
# Out:
# 첫번째 정수를 입력하세요3
# 두번째 정수를 입력하세요4
# 두 수의 합은 7

# %%
r=int(input('반지름 :'))
a=3.14*r*r
print(f'반지름{r}의 넓이는{a}')
# Out:
# 반지름 :5
# 반지름5의 넓이는78.5

# %%
pi=3.1415926
print(f'반지름 계산에 필요한 숫자는 {pi:.2f}')
# Out:
# 반지름 계산에 필요한 숫자는 3.14

# %%
print(f'{사과}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(f'{사과}')
#
# NameError: name '사과' is not defined
